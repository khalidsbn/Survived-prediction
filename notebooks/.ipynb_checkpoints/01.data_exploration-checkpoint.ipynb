# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/train.csv')

# %%
df.sample(10)
# Out:
#        PassengerId  Survived  Pclass               Name     Sex   Age  SibSp  \
# 31211        31211         0       2  Giordano, Timothy    male  19.0      0
# 69214        69214         0       2   Niemeyer, Walter    male  24.0      0
# 30546        30546         0       3       Garcia, Mark    male  12.0      0
# 64904        64904         1       2        Miller, Ted    male  49.0      0
# 91330        91330         0       3         Ward, Gary    male   2.0      4
# 43259        43259         1       2    Montague, Kelly  female  28.0      3
# 30683        30683         0       1   Stillson, Denise  female  29.0      0
# 2231          2231         1       2     Infield, Amber  female  48.0      1
# 37319        37319         0       3     Balnis, Daniel    male   9.0      0
# 28189        28189         0       1       Ramos, Cyril    male  58.0      0
#
#        Parch          Ticket    Fare   Cabin Embarked
# 31211      1          220554   33.23     NaN        S
# 69214      0          402272   12.33     NaN        S
# 30546      0             NaN    7.75     NaN        S
# 64904      1           29356   33.37     NaN        S
# 91330      1           26061   32.25     NaN        S
# 43259      0             NaN    9.59     NaN        S
# 30683      0     C.A. 310944   29.67  D23340        C
# 2231       1           10749   25.29     NaN        S
# 37319      0  SC/PARIS 38147   20.73     NaN        S
# 28189      0          492795  110.22   A7908        S

# %%
sns.heatmap(df.isna().T);

# %%
sns.distplot(df.Age)
plt.xlabel('')
plt.title('Age distribution');

# %%
sns.countplot(df, x='Sex', hue='Survived');

# %%
sns.countplot(df, x='Pclass', hue='Survived');
plt.title('1 = 1st, 2 = 2nd, 3 = 3rd (Class)');

# %%
sns.countplot(df, x='SibSp', hue='Survived');
plt.title('Number of Siblings for passengers:');

# %%
sns.countplot(df, x='Parch', hue='Survived');
plt.title('How many children that parents have');

# %%
sns.countplot(df, x='Embarked', hue='Survived');
plt.title('Port of Embarkation\nC = Cherbourg, Q = Queenstown, S = Southampton');
